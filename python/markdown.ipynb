# %%
import nltk
from nltk.tokenize import word_tokenize

# only needed the first time
nltk.download('punkt')

def average_word_length(filename):
    with open(filename, "r", encoding="utf-8") as f:
        text = f.read()
    
    words = word_tokenize(text)
    
    # keep only actual words (no punctuation)
    words = [word for word in words if word.isalpha()]
    
    if len(words) == 0:
        return 0
    
    avg = sum(len(word) for word in words) / len(words)
    return avg
# shows longest word
def longest_word(filename):
    with open(filename, "r", encoding="utf-8") as f:
        text = f.read()
    
    words = word_tokenize(text)
    words = [word for word in words if word.isalpha()]
    
    if not words:
        return ""
    
    return max(words, key=len)

print("Adventure Time Episodes by Average Word Length")
print("Episode 1:", average_word_length("ATE1.txt"), "longest word:", longest_word("ATE1.txt"))
print("Episode 2:", average_word_length("ATE2.txt"), "longest word:", longest_word("ATE2.txt"))
print("Episode 3:", average_word_length("ATE3.txt"), "longest word:", longest_word("ATE3.txt"))
print("Episode 4:", average_word_length("ATE4.txt"), "longest word:", longest_word("ATE4.txt"))
print("Episode 5:", average_word_length("ATE5.txt"), "longest word:", longest_word("ATE5.txt"))
print("Episode 6:", average_word_length("ATE6.txt"), "longest word:", longest_word("ATE6.txt"))
print("Episode 7:", average_word_length("ATE7.txt"), "longest word:", longest_word("ATE7.txt"))
print("Episode 8:", average_word_length("ATE8.txt"), "longest word:", longest_word("ATE8.txt"))
print("Episode 9:", average_word_length("ATE9.txt"), "longest word:", longest_word("ATE9.txt"))
print("Episode 10:", average_word_length("ATE10.txt"), "longest word:", longest_word("ATE10.txt"))
print("Episode 11:", average_word_length("ATE11.txt"), "longest word:", longest_word("ATE11.txt"))
print("Episode 12:", average_word_length("ATE12.txt"), "longest word:", longest_word("ATE12.txt"))
print("Episode 13:", average_word_length("ATE13.txt"), "longest word:", longest_word("ATE13.txt"))
print("Episode 14:", average_word_length("ATE14.txt"), "longest word:", longest_word("ATE14.txt"))
print("Episode 15:", average_word_length("ATE15.txt"), "longest word:", longest_word("ATE15.txt"))
print("Episode 16:", average_word_length("ATE16.txt"), "longest word:", longest_word("ATE16.txt"))
print("Episode 17:", average_word_length("ATE17.txt"), "longest word:", longest_word("ATE17.txt"))
print("Episode 18:", average_word_length("ATE18.txt"), "longest word:", longest_word("ATE18.txt"))
print("Episode 19:", average_word_length("ATE19.txt"), "longest word:", longest_word("ATE19.txt"))
print("Episode 20:", average_word_length("ATE20.txt"), "longest word:", longest_word("ATE20.txt"))
print("Episode 21:", average_word_length("ATE21.txt"), "longest word:", longest_word("ATE21.txt"))
print("Episode 22:", average_word_length("ATE22.txt"), "longest word:", longest_word("ATE22.txt"))
print("Episode 23:", average_word_length("ATE23.txt"), "longest word:", longest_word("ATE23.txt"))
print("Episode 24:", average_word_length("ATE24.txt"), "longest word:", longest_word("ATE24.txt"))
print("Episode 25:", average_word_length("ATE25.txt"), "longest word:", longest_word("ATE25.txt"))
print("Episode 26:", average_word_length("ATE26.txt"), "longest word:", longest_word("ATE26.txt"))
print("All files analyzed!")
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\curto\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# Adventure Time Episodes by Average Word Length
# Episode 1: 4.47965367965368 longest word: decorpsinator
# Episode 2: 4.197829716193656 longest word: sarcastically
# Episode 3: 3.9796015180265654 longest word: SOOOOOOOOOOOO
# Episode 4: 4.026951151038742 longest word: disappearance
# Episode 5: 4.24613987284287 longest word: dollaaaaaarrrrr
# Episode 6: 4.2110864745011085 longest word: extraordinary
# Episode 7: 4.384967919340055 longest word: hybernotalist
# Episode 8: 4.285465622280244 longest word: Impersonating
# Episode 9: 4.0691367456073335 longest word: indistinguishable
# Episode 10: 4.142437591776799 longest word: roughhousing
# Episode 11: 4.318369216674301 longest word: Unsympathetically
# Episode 12: 4.045871559633028 longest word: wawawawawawawawa
# Episode 13: 4.051529790660226 longest word: redoodoodiculous
# Episode 14: 4.1055634807417976 longest word: Ahahahahahehehe
# Episode 15: 4.131008980454306 longest word: malfunctioning
# Episode 16: 3.9697115384615387 longest word: manifestation
# Episode 17: 3.9607064017660045 longest word: bachelorette
# Episode 18: 4.077519379844961 longest word: elemeeeeeeeeent
# Episode 19: 4.139285714285714 longest word: sesquicentennial
# Episode 20: 3.9043414275202353 longest word: transforming
# Episode 21: 4.164675324675325 longest word: nonononononono
# Episode 22: 4.189432989690721 longest word: Prevaricating
# Episode 23: 4.209302325581396 longest word: incomprehensibly
# Episode 24: 4.069164265129683 longest word: psychologically
# Episode 25: 4.1052188552188555 longest word: enthusiastically
# Episode 26: 4.029931972789115 longest word: unapologetically
# All files analyzed!

# %% [markdown]
# ## WORKFLOW
# This python script analyzes the **Adventure Time episode transcripts** to measure:
# 1. Average word length per episode.
# 2. The longest word used in each episode. sometimes this would result in an output of a streched out word like "Nooooooooo".
#
# I used **Python** and **NLTK** for text processing.
#
# ## Tools and Libraries
# - **Python 3.12**
# - **NLTK**
#
# ## Method
# 1. Each transcript (ATE1.txt... ATE26.txt) was read into my Python.

# %%
with open(filename, "r", encoding="utf-8") as f:
        text = f.read()

# %% [markdown]
# 2. All words were extracted using **NLTK word_tokenize,** just like how we would with XSLT.
# 3. Punctuation and numbers were removed. using **NLTK Punkt**

# %% [markdown]
# 4. For each episode:
#    - **Average word length** = sum of word lengths ÷ number of words
#    - **Longest word** = word with the most letters

# %%
def average_word_length(filename):
    with open(filename, "r", encoding="utf-8") as f:
        text = f.read()
    
    words = word_tokenize(text)
    
    # keep only actual words (no punctuation)
    words = [word for word in words if word.isalpha()]
    
    if len(words) == 0:
        return 0
    
    avg = sum(len(word) for word in words) / len(words)
    return avg

def longest_word(filename):
    with open(filename, "r", encoding="utf-8") as f:
        text = f.read()
    
    words = word_tokenize(text)
    words = [word for word in words if word.isalpha()]
    
    if not words:
        return ""
    
    return max(words, key=len)

# %% [markdown]
# 5. Results were printed

# %% [raw]
# I found that the average word length each episode was about 3.9 to 4.5 letters long. Python told me that the first episode had the longest average of words, which I was not expecting. Some words were streched out making them the longest word or straight up random noises like "ahahahahahehehe"
